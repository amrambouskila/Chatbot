# %% [markdown]
# # Transformer Model

# %%
import re
import time
import pandas as pd
import numpy as np
import torch
from tqdm import trange
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from torch.cuda.amp import GradScaler, autocast
import math
from pathlib import Path
from datasets import load_dataset
from tokenizers import Tokenizer, pre_tokenizers, models, trainers
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import Whitespace
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import torch.optim as optim
import pynvml

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'The neural network will be running on {device}')
# Out:
# The neural network will be running on cuda

# %%
def relu(x):
    return torch.max(x, torch.tensor(0.0))

def softmax(x, dim: int = -1):
    max_val, _ = torch.max(x, dim=dim, keepdim=True)
    x_exp = torch.exp(x - max_val)
    sum_x_exp = torch.sum(x_exp, dim=dim, keepdim=True)
    return x_exp / sum_x_exp

# %%
class InputEmbeddings(nn.Module):
    def __init__(self, d_model: int, vocab_size: int):
        super().__init__()
        self.d_model = d_model
        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(vocab_size, d_model)

    def forward(self, x):
        if x is None:
            raise ValueError("Input to embedding is None")
            
        return self.embedding(x) * math.sqrt(self.d_model)

# %%
class FeedForwardBlock(nn.Module):
    def __init__(self, d_model: int, d_ff: int, dropout: int):
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
         return self.linear_2(self.dropout(torch.relu(self.linear_1(x))))

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, seq_len: int, dropout: float):
        super().__init__()
        self.d_model = d_model
        self.seq_len = seq_len
        self.dropout = nn.Dropout(dropout)

        pe = torch.zeros(seq_len, d_model)
        position = torch.arange(0, seq_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -math.log(10000) / d_model)

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        pe = pe.unsqueeze(0)

        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + (self.pe[:, :x.shape[1], :]).requires_grad_(False)
        return self.dropout(x)

# %%
class LayerNormalization(nn.Module):
    def __init__(self, eps: float = 10 ** -6):
        super().__init__()
        self.eps = eps
        self.alpha = nn.Parameter(torch.ones(1))
        self.bias = nn.Parameter(torch.zeros(1))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        std = x.std(dim=-1, keepdim=True)
        return self.alpha * ((x - mean) / torch.sqrt(std + self.eps)) + self.bias

# %%
class FeedForwardBlock(nn.Module):
    def __init__(self, d_model: int, d_ff: int, dropout: int):
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    
    def forward(self, x):
         return self.linear_2(self.dropout(relu(self.linear_1(x))))

# %%
class MultiHeadAttentionBlock(nn.Module):
    def __init__(self, d_model: int, h: int, dropout: int):
        super().__init__()
        self.d_model = d_model
        self.h = h
        assert d_model % h == 0, 'd_model is not divisible by h'
        self.d_k = d_model // h
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_o = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)

    @staticmethod
    def attention(query, key, value, mask, dropout: nn.Dropout):
        d_k = query.shape[-1]
        attention_scores = ((query @ key.transpose(-2, -1)) / (math.sqrt(d_k)))
        
        if mask is not None:
            attention_scores.masked_fill_(mask == 0, -1e9)
            
        attention_scores = softmax(attention_scores)
        
        if dropout is not None:
            attention_scores = dropout(attention_scores)
                        
        return attention_scores @ value, attention_scores
        
    def forward(self, q, k, v, mask):
        query = self.w_q(q)
        key = self.w_k(k)
        value = self.w_v(v)
        query = query.view(query.shape[0], query.shape[1], self.h, self.d_k).transpose(1, 2)
        key = key.view(key.shape[0], key.shape[1], self.h, self.d_k).transpose(1, 2)
        value = value.view(value.shape[0], value.shape[1], self.h, self.d_k).transpose(1, 2)
        x, self.attention_scores = MultiHeadAttentionBlock.attention(query, key, value, mask, self.dropout)
        x = x.transpose(1, 2).contiguous().view(x.shape[0], -1, self.h * self.d_k)
        return self.w_o(x)

# %%
class ResidualConnection(nn.Module):
    def __init__(self, dropout: float):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        self.norm = LayerNormalization()

    def forward(self, x, sublayer):
        return x + self.dropout(sublayer(self.norm(x)))

# %%
class EncoderBlock(nn.Module):
    def __init__(self, self_attention_block: MultiHeadAttentionBlock, feed_forward_block: FeedForwardBlock, dropout: float):
        super().__init__()
        self.self_attention_block = self_attention_block
        self.feed_forward_block = feed_forward_block
        self.residual_connections = nn.ModuleList([ResidualConnection(dropout) for _ in range(2)])

    def forward(self, x, src_mask):
        x = self.residual_connections[0](x, lambda x: self.self_attention_block(x, x, x, src_mask))
        x = self.residual_connections[1](x, self.feed_forward_block)
        return x

# %%
class Encoder(nn.Module):
    def __init__(self, layers: nn.ModuleList):
        super().__init__()
        self.layers = layers
        self.norm = LayerNormalization()

    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
            
        return self.norm(x)

# %%
class DecoderBlock(nn.Module):
    def __init__(self, self_attention_block: MultiHeadAttentionBlock, cross_attention_block: MultiHeadAttentionBlock, feed_forward_block: FeedForwardBlock, dropout: float):
        super().__init__()
        self.self_attention_block = self_attention_block
        self.cross_attention_block = cross_attention_block
        self.feed_forward_block = feed_forward_block
        self.residual_connections = nn.ModuleList([ResidualConnection(dropout) for _ in range(3)])

    def forward(self, x, encoder_output, src_mask, tgt_mask):
        x = self.residual_connections[0](x, lambda x: self.self_attention_block(x, x, x, tgt_mask))
        x = self.residual_connections[1](x, lambda x: self.cross_attention_block(x, encoder_output, encoder_output, src_mask))
        x = self.residual_connections[2](x, self.feed_forward_block)                         
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, layers: nn.ModuleList):
        super().__init__()
        self.layers = layers
        self.norm = LayerNormalization()

    def forward(self, x, encoder_output, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, encoder_output, src_mask, tgt_mask)
            
        return self.norm(x)

# %%
class ProjectionLayer(nn.Module):
    def __init__(self, d_model: int, vocab_size: int):
        super().__init__()
        self.proj = nn.Linear(d_model, vocab_size)

    def forward(self,x):
        return torch.log(softmax(self.proj(x), dim=-1))

# %%
class Transformer(nn.Module):
    def __init__(self, 
                 encoder: Encoder, 
                 decoder: Decoder, 
                 src_embed: InputEmbeddings, 
                 tgt_embed: InputEmbeddings, 
                 src_pos: PositionalEncoding, 
                 tgt_pos: PositionalEncoding, 
                 projection_layer: ProjectionLayer):

        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.src_embed = src_embed
        self.tgt_embed = tgt_embed
        self.src_pos = src_pos
        self.tgt_pos = tgt_pos
        self.projection_layer = projection_layer

    def encode(self, src, src_mask):
        src = self.src_embed(src)
        src = self.src_pos(src)
        return self.encoder(src, src_mask)

    def decode(self, encoder_output, src_mask, tgt, tgt_mask):
        tgt = self.tgt_embed(tgt)
        tgt = self.tgt_pos(tgt)
        return self.decoder(tgt, encoder_output, src_mask, tgt_mask)

    def forward(self, src, tgt, src_mask=None, tgt_mask=None):
        # Encode the source sequence
        encoder_output = self.encode(src, src_mask)
        
        # Decode the target sequence
        decoder_output = self.decode(encoder_output, src_mask, tgt, tgt_mask)
        
        # Project the decoder output to the vocabulary space
        output = self.projection_layer(decoder_output)
        
        return output

# %%
def build_transformer(src_vocab_size: int, 
                      tgt_vocab_size: int, 
                      src_seq_len: int, 
                      tgt_seq_len: int, 
                      d_model: int = 512, 
                      N: int = 6, 
                      h: int = 8, 
                      dropout: float = 0.1, 
                      d_ff: int = 2048
                     ) -> Transformer:

    src_embed = InputEmbeddings(d_model, src_vocab_size)
    tgt_embed = InputEmbeddings(d_model, tgt_vocab_size)
    src_pos = PositionalEncoding(d_model, src_seq_len, dropout)
    tgt_pos = PositionalEncoding(d_model, tgt_seq_len, dropout)
    
    encoder_blocks = []
    for _ in range(N):
        encoder_self_attention_block = MultiHeadAttentionBlock(d_model, h, dropout)
        feed_forward_block = FeedForwardBlock(d_model, d_ff, dropout)
        encoder_block = EncoderBlock(encoder_self_attention_block, feed_forward_block, dropout)
        encoder_blocks.append(encoder_block)

    decoder_blocks = []
    for _ in range(N):
        decoder_self_attention_block = MultiHeadAttentionBlock(d_model, h, dropout)
        decoder_cross_attention_block = MultiHeadAttentionBlock(d_model, h, dropout)
        feed_forward_block = FeedForwardBlock(d_model, d_ff, dropout)
        decoder_block = DecoderBlock(decoder_self_attention_block, decoder_cross_attention_block, feed_forward_block, dropout)
        decoder_blocks.append(decoder_block)

    encoder = Encoder(nn.ModuleList(encoder_blocks))
    decoder = Decoder(nn.ModuleList(decoder_blocks))
    projection_layer = ProjectionLayer(d_model, tgt_vocab_size)
    transformer = Transformer(encoder, decoder, src_embed, tgt_embed, src_pos, tgt_pos, projection_layer)

    for p in transformer.parameters():
        if p.dim() >1:
            nn.init.xavier_uniform_(p)

    return transformer

# %% [markdown]
# # Load in Data

# %%
load_dataset("Fishball02/anime-subtitle-dragon-ball")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['episode', 'start', 'end', 'text'],
#         num_rows: 27187
#     })
# })

# %%
load_dataset("Fishball02/anime-subtitle-dragon-ball")['train']['text']
# Out:
# ["What's this...?",
#  'Unfortunately, the Red Ribbon\\NArmy will be taking that treasure.',
#  'If you wanna fight, then go ahead and try!',
#  'My, how confident...',
#  "You bastard! You'll regret that!",
#  "I... can't move...!",
#  'See you in the next world!',
#  'G-Goku...!',
#  '"The Eyes that Sparkle with Terror"',
#  "I'll show you just how terrible\\NI can be! In full amount!",
#  'You should be honored to die by my hands!',
#  'You talk too much...!',
#  "Every time I'm about to kill scum such as yourself...",
#  '...each and every strand of my beautiful hair...',
#  '...and my white, glowing skin tremble with pleasure!',
#  'Come at me!',
#  "What's with you?! You gross me out!",
#  'Now you said it!',
#  'Pandas on a picnic!',
#  'G-Goku!',
#  "Such nice friends!\\NHere's another freebie!",
#  'The Dragon Ball absolutely...',
#  'Die!',
#  'H-How dare you discolor my pink cheeks...?!',
#  "Now it's my turn! Here I come!",
#  "You're nothing special!",
#  'A-Amazing!',
#  "Goku's grown even stronger than he was at the Tenkaichi Tournament...!",
#  'Aw man, I thought you were stronger than that!',
#  "You'll pay!",
#  "You'll pay for that!",
#  "No, don't! Don't!",
#  "W-What's going on...?!",
#  "I... can't move...",
#  'Too late...!',
#  'What do you think...',
#  '...of my psychic ability?',
#  'Damn, what is this...?!',
#  'You really socked it to me just now...!',
#  'Thanks for earlier!',
#  'What happened to all that liveliness you just had?',
#  "I'll cheer you back up...",
#  'Here we go...',
#  "It's really starting to come down now!",
#  'Unfortunately, it looks like\\NI need to get out of here',
#  'with the Dragon Ball and the treasure as quickly as possible...',
#  "You! Girl! You know where the Dragon Ball is, don't you?!",
#  'Tell me where, or I shoot the kid!',
#  'Well?!',
#  'Oh, r-right...',
#  'Judging from the location on the radar...',
#  "It's probably at the bottom of that pool!",
#  'D-Damn it...!',
#  'Thank you! I no longer have any use for the lot of you!',
#  'Oh, what a pity!',
#  'Everyone who defies the Red\\NRibbon Army must be put to death!',
#  "W-What?! But didn't I just tell you where the Dragon Ball is?!",
#  "That's not fair!",
#  'Not fair? What a beautiful phrase!',
#  'Well, time to die!',
#  "A-And then I'll be the next one to die...!",
#  "Even though I'm so cute!",
#  'You sure can talk a lot at a time like this.',
#  'D-Dammit...!',
#  'Farewell!',
#  'Eek! A mouse! A mouse!',
#  'Unclean! Unclean!',
#  'Oh! I can move!',
#  'Look! His psychic powers wore off thanks to the mouse!',
#  "Now! Get 'im!",
#  "You're in for it now!",
#  'Oh, no! My psychic ability...!',
#  'Your penalty is my paper-scissor-rock attack!',
#  "W-What?! Alright, I'll do it again!",
#  "Oh, no you don't!",
#  'My eyes! My eyes...!',
#  'Paper-scissors-rock!',
#  'You did it!',
#  '--Hurray!\\N--Peace! Peace!',
#  "This whole area's about to come down!",
#  'Bulma!',
#  'I thought for sure that you fell in...',
#  "You're too greedy!",
#  'Stop gawking and help me out!',
#  'Oh...',
#  'W-We need to get out of here fast!',
#  "It's too bad, but I think you're right!",
#  "Bulma! Where's the Dragon Ball?",
#  'The bottom of that pool, but forget about it!',
#  "There's no time!",
#  'You two go on ahead!',
#  "I'll escape right after\\NI find the Dragon Ball!",
#  'Okay...!',
#  "That's crazy!",
#  'That jerk!',
#  "Nothing we can do now!\\NLet's go on ahead and wait for him!",
#  "If it's like this here, then the path back to our mini-sub must already be...",
#  '...blocked off! But still...',
#  '--...all we can do now is run!\\N--Yeah!',
#  "It's really falling apart now!",
#  "Let's see...",
#  'Where are you?!',
#  'Hurry!',
#  "Great! The path's still open!",
#  'Yay!',
#  '--A-Are we still alive...?\\N--Yeah, somehow...',
#  "But the exit's closed off now...",
#  'We have to find some other way out!',
#  "That's it! As it's already a sink-or-swim situation, let's try that mini-sub!",
#  "If we're lucky, we might be able to get outside!",
#  "Goku's still not here...\\NWhat's he doing?!",
#  'Not here!',
#  'Not here!',
#  'There you are!',
#  'Got ya!',
#  'Ow...!',
#  "I owe you my life, so I'll help you out!",
#  'Get inside my mouth!',
#  'So beautiful...!',
#  'All of this treasure is mine!\\NMine and mine alone!',
#  'The jewels, the gold, the coins!',
#  'The engine started! We can leave!',
#  'Goku! Where are you?!',
#  'Hurry up!',
#  'Goku!',
#  "No good! We can't wait any longer!",
#  "We're diving! Hurry and close the hatch!",
#  'Are you just gonna leave Goku here to die?!',
#  "What're you talking about?!",
#  'To be blunt, the most important thing in this world to me is my own life!',
#  'What about you?!',
#  'S-Same here, but...',
#  "Don't worry, he won't kick the bucket so easily!",
#  'Kuririn! Here we go!',
#  "If we can't get out into the ocean by diving down here, then it's all over!",
#  'Contestant Son Goku, despite his small frame,',
#  'has vanquished Contestant\\NGiran with his tremendous power!',
#  '"Kuririn\'s Desperate\\NOffensive and Defensive Battle"',
#  'It was true of Contestant\\NKuririn from the first match.',
#  'What on earth is the source of the strength of these two,',
#  'who both wear the same Circle- turtle mark on their uniforms?',
#  'And so, now, before the semifinals begin,',
#  'we are joined by Contestant Kuririn,',
#  'and we would like to have an interview with these two.',
#  'If he transforms at the full moon,',
#  "there'll be more commotion than just the tournament!",
#  "All we can do is pray that the moon doesn't come out!",
#  'So, you have a tail, then?',
#  'Mm-hmm. It got pulled off once, but I guess it grew back out, huh?',
#  'Both of you, congratulations on reaching the semifinals.',
#  "And despite being so small, you're absolutely amazing!",
#  'Contestant Kuririn, as I recall, was 13 years old.',
#  'Contestant Son, how old are you?',
#  "What's this? Are you giving it to me?",
#  "D-Dummy! That's a mike!",
#  '--A bike?\\N--A mike!',
#  "It's a device that makes your voice louder!",
#  'Your gag just now was quite well received.',
#  "D-Don't embarrass us! All you have to do is answer the question!",
#  'The question?',
#  "Ah, my age! Let's see... 9, 10, 11, 12... Got it! I'm twelve years old!",
#  "But I remember you saying you were fourteen, didn't you?",
#  'Earlier, the Old-timer was teaching us math, right?',
#  'There, twelve comes after eleven.',
#  "I'd thought that fourteen came after eleven!",
#  "He's twelve? And here I'd always thought he was too little, all things considered!",
#  "His hair hadn't even come in!\\NHe really is an idiot!",
#  "What's this, Goku? Your age was even lower than mine?",
#  'But Kuririn, your height is still lower than mine!',
#  'Is that right?',
#  'The youngest participant in the tournament is Contestant Son, then?',
#  'By the way, about that tail of yours-- is it a real tail?',
#  "Yeah, about that-- it's strange that it would suddenly grow out!",
#  "Besides, I've never even heard of a human who had a tail!",
#  "It's a real tail, I tell you.\\NHow about I show you?",
#  'You see? Yeah?',
#  "S-Stop that! You're being a disgrace!",
#  "See? It's real, right?",
#  'We know!',
#  "You two! You're not doing some routine on purpose here, right?",
#  "G-Goku may be strong, but his shameless character hasn't changed at all!",
#  'Indeed, indeed!',
#  'Incidentally, the two of you are both wearing the same uniform.',
#  'Exactly which Dojo did you learn your fighting technique from?',
#  "There wasn't any Dojo in particular.",
#  'Muten Roshi, he said!',
#  "It's no wonder those pipsqueaks are so incredible!",
#  'Yes. He said he was no longer taking any pupils,',
#  'but he made a special exception.',
#  'I-Incredible! Absolutely incredible!',
#  'That explains why they are so uncommonly strong!',
#  'Even so, that such a person should still be alive...!',
#  'What is it?',
#  'What?',
#  "I've thought for a little while now that it was most peculiar...",
#  'Is that what it looks like to you?',
#  '--Yeah.\\N--I see...',
#  "In that case, I've got no choice but to tell you the truth...",
#  'I am...',
#  'Jackie Chun!',
#  'At last, the semifinals!',
#  'Contestant Kuririn, what do you think of your opponent, Contestant Jackie?',
#  'He is, indeed, a powerful challenger.',
#  "then he doesn't pose any problem for you, does he?",
#  "Y-Yes, I suppose you're right.\\NMy opponent is an elderly man, and all.",
#  'Your techniques, your lecherous qualities...',
#  '...and even your faces, if you look closely, are exactly the same!',
#  "That's a wig, right? On your head?",
#  'Contestant Jackie Chun, please come forward!',
#  'I have to go.',
#  "Strange! It isn't possible that his resemblance is accidental!",
#  'Yo!',
#  'Contestant Jackie has arrived!',
#  'Now then, with no further ado... let the match beg--!',
#  "What's this? You're not going to interview me?",
#  'Y-Yes, yes, indeed...',
#  'Give me that!',
#  'One! Two!',
#  'One, two, three, four!',
#  'That cute kid over there is a girl!',
#  'Hey, hey, hey! Hey, hey, hey!',
#  "She's got boobies, but she hasn't got a winky!",
#  'Hey, hey, hey!',
#  'I invite you to the village festival!',
#  'Hey, hey, come on!',
#  "We'll take my tractor, get on!",
#  'When you dance to the rhythm of the drum!',
#  'It becomes the Bon festival dance!',
#  'Thank you, thank you!',
#  'We did it!',
#  'Here!',
#  'Match 5, begin!',
#  "You're pretty good, to make me put my hand out.",
#  'Now, then...',
#  'H-His punch...',
#  "I-I didn't see it... at all...!",
#  "He's no ordinary fighter, that old guy!",
#  'S-So it seems...!',
#  'W-What an incredible punch!',
#  'What are you saying?!',
#  '--Watch closely!\\N--Goku!',
#  'You should have seen the punch! You trained, right?',
#  'Oh, yeah?',
#  "Watch carefully!\\NYou'll definitely see it!",
#  "Oh? You're not conceding?",
#  "This time, the punch won't be as untrained as that last one...",
#  'I see it!!',
#  "There, you see?\\NYou can see it, can't you?!",
#  'Yeah!',
#  "You've done well to see through that.",
#  'W-What was that j-just now?!',
#  'We were completely unable to see...!',
#  "It's been a long time since anyone could keep up with my speed.",
#  'Well then, how about this...?',
#  "That's just what I want!",
#  'Aw, geez...!',
#  'Contestant Kuririn has gone down!',
#  'I will begin the count! 1... 2... 3...',
#  "H-He's not getting up!",
#  "Maybe he's been knocked out!",
#  '4...',
#  "Get up, Kuririn! You're going to lose!",
#  'Stick with it!',
#  '5...',
#  'Kuririn, I say!',
#  '6...',
#  "That's it! Now get up!",
#  "--We'll see if he can get up.\\N--7...",
#  '--Get up!\\N--8...',
#  '9...',
#  'Oh, my!',
#  "--He got up!\\N--He's up! He's up! He's up!",
#  'Contestant Kuririn has risen to his feet!',
#  '--Oh, yow!\\N--You did it! Great!',
#  'Um...',
#  'Excuse the interruption in the middle of the match,',
#  'but just now, in that one instant,',
#  'we were unable to see what happened at all.',
#  'Would you give an account of it for us?',
#  'What? What am I going to do with you?',
#  "I'll show it to you in slow motion, so watch carefully!",
#  'Yes, if you would be so kind!',
#  'First, I went at him like this...',
#  'Then, Kuririn came at me...',
#  'I see...',
#  'And so, I put forth a kick...',
#  'Then I avoided the kick, like this.',
#  "I then threw a punch at my opponent's face...",
#  'But, he tried to spit on my fist,',
#  'and because it would have been dirty, I pulled back.',
#  'At that opening, I went to punch him with my left hand...',
#  'But he shot boogers at me, so I pulled back!',
#  'At that point, I decided to change my strategy.',
#  'I worked out my strategy, too.',
#  'Up to this point, it took about 0.2 seconds.',
#  'I decided on a strategy a moment earlier than he did...',
#  "All right! Let's do it this way!",
#  "We'll do Rock-Paper-Scissors!",
#  'What? All right! Fine!',
#  '...I said, without thinking, which was my mistake!',
#  'Rock-Paper-Scissors!',
#  'Now look this way!',
#  'At this point, I was a fool for seriously doing the "Look this way" part.',
#  'You idiot! You left yourself open!',
#  'Immediately, I jumped...',
#  'Hey, there...',
#  'Would you hold me up for a moment?',
#  'Y-Yes. A jumping scene, right?',
#  'So, I jumped like this...',
#  '...and kicked him from behind...',
#  "Okay, you'll have to carry me throughout this whole part.",
#  'This is the scene where\\NI finish up with style.',
#  "I-I'm sure it was right around here, right, where you landed?",
#  'And here I ended up, looking good!',
#  'Say there, help me out here as well!',
#  'Having taken a kick to the back of the head, I was knocked flying...',
#  'R-Right, right. L-Like this?',
#  'Ah, right around here, I made a flip...',
#  'A flip?',
#  'W-Whoosh...?',
#  '--Be careful!\\N--P-Pardon me.',
#  'Somehow or other, I regained my balance and landed...',
#  '...but as it turned out, the damage was too great, and I fell over.',
#  'A-All of this...?',
#  'Y-You did all of this in that one moment...?!',
#  'I-I-Incredible!',
#  "Quite frankly, this is the first time I've ever seen such stunningly fast techniques!",
#  'Please excuse the interruption!\\NNow then, please continue your match!',
#  'You fell for it!',
#  "N-Now I've done it!",
#  'You did it!',
#  "I've won!",
#  'I let myself get enticed by panties!',
#  "I-It can't be!",
#  "If that person were Muten Roshi, then he wouldn't lose like this...!",
#  'Uh-oh! Contestant Jackie Chun, what a pathetic way to lose!',
#  'Still, there is nothing he can do here!',
#  "D-Damn! If I fall like this, I'll lose!",
#  "It can't be avoided...",
#  "I'm back.",
#  'W-W-What was that?! What was that?!',
#  "I-It seems like we've seen that somewhere before...",
#  'You could say.',
#  "T-That couldn't be...!",
#  "I had heard that there's only one person in the world who can do this technique,",
#  'but there is someone else here who can, as well!',
#  'Goku! What should I do?!',
#  'Win! The only thing you can do is win!',
#  "That doesn't make for any advice, you know!",
#  'Now then, this has gone on long enough,',
#  "and we can't let it interfere with the final round...",
#  'Shall we end it here?',
#  'Dammit... At this point, it\'s "Nothing ventured, nothing gained!"',
#  'Looks like it was the gate that got smashed!',
#  'Y-Yow! You shut up! Shut your mouth!',
#  "Kuririn! Behind you!\\NHe's swung around behind you!",
#  "--Peace!\\N--He's down! Contestant Kuririn is down!",
#  '--1... 2... 3...\\N--Counting is useless.',
#  "He won't be getting up for a bit.",
#  '--4... 5...\\N--What speed!',
#  '--6... 7...\\N--For him to leave an afterimage, then swing around behind...',
#  "--8... 9...\\N--He's had it.",
#  '10! Contestant Kuririn is knocked out!',
#  'Contestant Jackie Chun wins and moves on to the final round!',
#  'Hey, are you okay?',
#  "You still haven't had enough training, huh?",
#  'You sure are persistent!',
#  "Yamucha, what are you saying?\\NThe Old-timer doesn't have any hair!",
#  'And if this is a wig...?\\NExcuse me a moment...!',
#  'W-What are you doing?!',
#  '--Huh?\\N--That hurts, you know!',
#  'I get it! That hair is real, and your usual bald look is a wig!',
#  'Is there anyone that would purposely wear a bald wig all the time?!',
#  'Come to mention it, his face and his voice are awfully similar...',
#  "That ain't the Old-timer's scent.\\NHe smells something like oranges.",
#  "That's perfume!",
#  "It's a citrus blend of eau-de-Cologne.\\NI am a gentleman, after all.",
#  "I'm going to tell you now, I am\\NJackie Chun, not Muten Roshi!",
#  'And now, we will begin the second match!',
#  'Contestant Son Goku and Contestant\\NNamu, please come forward!',
#  "It's my turn!",
#  'Goku! Go on to the final round, and get him back for me!',
#  "Mm-hmm! I'll do my best! All right...",
#  'As stern an expression as ever!',
#  "We've made it all the way out to the ocean place.",
#  'We still got a little ways to go...',
#  'It sure is far...',
#  'It can...',
#  "If I knew it was going to be like this,\\NI would've brought a machine to ride.",
#  'Go! Go! Go faster!',
#  'I get it already!',
#  'Eh? What is?',
#  '"Bulma\'s Big Failure"',
#  'It appears the boy is heading toward the Dragon Ball',
#  "that General Blue is in charge of, doesn't it?",
#  'Yes... What speed...!',
#  'That damn runt...!',
#  "The kid's photograph has been transmitted, yes?",
#  'Yes, sir!',
#  'Contact General Blue!',
#  'Tell him to use full force to kill the boy the instant they find him!',
#  'Yes, sir!',
#  'General Blue! The submarine team has contacted us!',
#  "Alright. I'll be there right away!",
#  "What did you say?!\\NThey still can't find it?!",
#  'N-No...',
#  'Give me a break!\\NCommander Red will be furious!',
#  "They're trying their very hardest to find it,",
#  "but they're having a difficult time, as it appears to be on the ocean floor.",
#  "I don't want to hear your excuses!",
#  'Hey, you there!',
#  "You were picking your nose just now, weren't you?",
#  'Uh, well, um...!',
#  'How filthy!',
#  'Execute him at once!',
#  'Help...! I have a wife and kids...!',
#  'What beautiful sounds...',
#  'Hey, disinfect that area, will you?',
#  'Yes, sir!',
#  'General Blue! Message from headquarters!',
#  '--Headquarters?\\N--Yes!',
#  "It appears the kid's heading this way!",
#  'What? The kid...?',
#  'Heading toward me, General Blue, eh?',
#  'I heard he wiped out the\\NSilver and White units!',
#  'And your point is?',
#  "N-No, it's just that...",
#  "They're embarrassments to the Red Ribbon Army.",
#  'Things have become a lot more interesting...',
#  "This time it's a really hot place!",
#  'Should be there soon...',
#  "I sure hope the next one is Grandpa's Four-Star Ball...",
#  'What are those?',
#  'Wow! Amazing!',
#  'Later!',
#  'Stop! Stop!',
#  "The Dragon Ball's around here, below us!",
#  'Eh?! Below us...?',
#  "But it's nothing but water; there isn't anything here...",
#  'It must be at the bottom of the ocean!',
#  'It fell into the water?',
#  "Okay! For now, let's land on a nearby island.",
#  "--That's a good one!\\N--Okay!",
#  "It doesn't look like it's deserted.",
#  "See, there's even a boat...",
#  'It was cramped in there!',
#  "I'm gonna go dive into the ocean and look for it now!",
#  "There's no need to do anything that primitive!",
#  'You should be thankful I came with you.',
#  'Good thing I prepared a submarine capsule for just such a situation!',
#  "What's wrong?",
#  'W-Why is there only one in here?!',
#  'Unless...',
#  "...it's Dad's...",
#  'I brought the wrong one...!',
#  "Say, what's inside it?",
#  "I... don't really want to see...",
#  'I get a really bad feeling about this...!',
#  'It might be a really useful capsule...',
#  'Useful?!',
#  'I have faith in you, Dad!',
#  "Weird! They're all naked, but they're not taking baths...",
#  "That isn't for kids!",
#  "--Why not?\\N--It just isn't!",
#  'That dirty old man!',
#  "I'll never trust him again!",
#  'Say...',
#  'What?!',
#  "I guess I'll dive into the water and look for the Dragon Ball after all.",
#  'Yeah, do whatever you want...!',
#  'Later!',
#  "Let's see... I think it was around here somewhere...",
#  'Even though the ocean is deep...',
#  "That's it!",
#  'Hey! Bulma!',
#  'Oceans are really deep, huh?!',
#  "I can't hold my breath that long!",
#  'Huh? Where did she go?',
#  'It looks like people live here, so they must at least sell capsules...',
#  'What pretty flowers!',
#  'What a surprise...',
#  "But it doesn't feel like anyone's here at all...",
#  'Huh?',
#  'What could those be?',
#  'Hey! Yoo-hoo!',
#  'Hey!',
#  "H-Hey! What're you doing?!",
#  "Hey! It ain't him!",
#  "It ain't the boy!",
#  "It's a girl!",
#  "I-It's all over...",
#  "Sorry 'bout that...",
#  'We thought you were someone else...',
#  'Someone else...?!',
#  "Don't be stupid! That was dangerous!",
#  'I almost died!',
#  '--No need to get so mad...\\N--What?!',
#  "It's partly your fault for wandering around in a place like this!",
#  "What exactly were you doin' anyway?",
#  "If you'd just listen...",
#  'Oh, perfect timing!',
#  'Do you know of any places on this island that sell capsules?',
#  'Capsules?',
#  "I've been looking for a place but haven't found any...",
#  "This island's deserted.\\NAin't no places sellin' any...",
#  'Deserted? No way...',
#  "That's strange, I saw a ship earlier...",
#  'Hey! Bulma! Bulma!',
#  'Where did she go...?',
#  'Ow...!',
#  'Yummy!',
#  'What? Is something wrong?',
#  'No, nothing... But you sure are a cute girl...',
#  'Fer sure...',
#  'Oh! You could tell, huh?',
#  'So, how old are ya?',
#  'Sweet sixteen!',
#  'Sixteen...!',
#  'Say, wanna do something fun with us?',
#  'Eh? Something fun?',
#  "You don't mean videogames, do you?",
#  'Of course not.',
#  'Not tag or Hide-and-Go-Seek...',
#  'Nope.',
#  "It wouldn't be a riddle game, would it...?",
#  'No!',
#  "Then... you don't mean...",
#  "that you can't do in a gag anime meant for good boys and girls...?!",
#  'Bingo!',
#  "That's right!",
#  'Why, you...!',
#  'Blehhh!',
#  'Damn her...!',
#  'Help!',
#  'So full!',
#  "That's Bulma's voice...",
#  'Oh! There she is!',
#  "What's she doing...?",
#  'Help...!',
#  "I don't know what she's doing, but she sure gets into a lot of trouble!",
#  'Eh?! W-What the...?!',
#  'Where were you?!',
#  "Hey! What're you doing? Are those bad guys?",
#  "That's right! Hurry and beat 'em up!",
#  "He's...",
#  '...the boy!',
#  'Eh?! It is?!',
#  'Whoa!',
#  "You big jerk! You're with the\\NRed Ribbon Army too, aren't you?!",
#  'What?!',
#  'Extend, pole!',
#  'Revert, pole!',
#  'Peace! Peace!',
#  'General Blue!',
#  'Reconnaissance crafts 23 and 27 have disappeared from radar!',
#  "So you're here...",
#  "I'll let you have a bit of fun...",
#  'H-Hey...',
#  "You didn't need to go that far, did you?",
#  'They were just a couple of perverts...',
#  'Hey! I just had a good idea!',
#  "Old-timer Turtle Hermit's house isn't that far from here!",
#  "I bet he'll have a capsule that lets us go underwater!",
#  'T-The Turtle Hermit...?',
#  "Isn't there anything dirty... I mean interesting... to do around here?",
#  'The Turtle Hermit...',
#  'The Turtle Hermit... I dunno...',
#  "Let's stop by and see him real quick!",
#  "I'm smart too, huh?!",
#  'He says he wants you to fix this!',
#  'This? What is it?',
#  'A Dragon Radar!',
#  'Dragon Radar...?',
#  '"A Face-off! Arale vs. Blue"',
#  'Hey. Do you think you can fix the Dragon Radar?',
#  'Right?',
#  'I don\'t know the meaning of the word "impossible"!',
#  'It sure has been a long time, Your Majesty!',
#  "Urth hasn't changed one bit!",
#  'By the way, what exactly are we doing this for?!',
#  "Ain't it obvious?!",
#  "We steal Urth's resources, take 'em back to our home planet,",
#  'and just watch the dough roll in!',
#  'It looks like ordinary junk to me, though...',
#  "Shut up! No complainin'!",
#  "Now get collectin'!",
#  'It appears to be a special type of metal...',
#  'It could be the very latest in Urth technology...',
#  "What're you doin'?! Hurry and pick it up!",
#  'Yes, sir!',
#  "Come on! Let's scram before its owner comes lookin' for it!",
#  'Yes, sir!',
#  'So he got on the cloud and then zoom! He flew off like a rocket!',
#  "I wish I could've seen it!",
#  'Goku, I think his name was...',
#  'Come to think of it, he was dressed like a kung fu guy!',
#  "You sure you don't know him, Tsukutsun?",
#  "No, I don't know anybody like that...",
#  '--Taro!\\N--Taro! What happened?!',
#  'T-Terrible news! Let me use your phone!',
#  'Red Ribbon...! The Red Ribbon Army...',
#  'Are you all right?',
#  'Y-Yeah, I should have it soon...',
#  'Hey! What are Dragon Balls?',
#  "They're round balls about this big!",
#  "There's seven of them, and if you gather them all,",
#  "they'll grant you any wish you want!",
#  'Here are some snacks, you guys!',
#  'Yay!',
#  'Have as many as you like!',
#  'They look yummy!',
#  "You're so great, Dad!\\NIt looks like it's fixed!",
#  'R-Really? I barely even touched it...',
#  'How wonderful!',
#  'The Dragon Balls and wishes!\\NWhat a romantic story!',
#  'Let me think...\\NFirst, for my breasts to grow...',
#  'Um, you can only ask Shen Long one wish.',
#  'How come?',
#  "--How come? I don't know, either...\\N--Hey! It's fixed!",
#  'Really?!',
#  "Yay! It's fixed!",
#  'Here you are!',
#  "You did it! It's fixed!",
#  'Thanks!',
#  "Yay! It's fixed!",
#  'See! I truly am a genius!',
#  'Huh?',
#  "What's wrong?",
#  "There's a Dragon Ball right around here...",
#  'I found it!',
#  "--See?\\N--No, they're bigger than that.",
#  'That way!',
#  'Is it this way?',
#  'Or this way...?',
#  "It looks like it's close by, but something's strange...",
#  'Come on! Hurry up, you guys!\\NGet the lead out!',
#  'All set!',
#  'I am!',
#  "Don't aim this way!",
#  "He's insanely strong!",
#  "He's here!",
#  "But what's the Red Ribbon Army doing here in the sticks?!",
#  'They might be planning to take over Penguin Village!',
#  "I won't let them do that!",
#  "T-They can't seriously want to take over Penguin Village...!",
#  'Could it be true?',
#  "We can't stand up to them!\\NLet's surrender, Chief!",
#  "Don't be stupid! We're police officers!",
#  'We must protect the town, even if it means death!',
#  "That's right! Let's blast them!",
#  'I think maybe I chose the wrong profession...',
#  'This way.',
#  'In here!',
#  "That's weird...",
#  "That's weird. The radar says it's here...",
#  "Maybe it's the next one over?",
#  "No, it's back this way.",
#  'This way!',
#  'How strange...',
#  'In here!',
#  'So we meet again...',
#  'Dammit...! Let her go!',
#  "Don't move!",
#  'You all stay right there, or she dies!',
#  'Damn you...!',
#  "Listen up! She dies if you don't do what I say!",
#  'Um...',
#  "I'm not sure who you are, but doing that is dangerous...",
#  "That's right! One little slice and her head comes off!",
#  "No, that's not what I mean...",
#  'W-What exactly are you trying to say?!',
#  'Hey! Give me back my Dragon Balls!',
#  'Oh, no...!',
#  "W-What is it?! What's wrong?!",
#  "I... can't move...!",
#  "Y-You can't move...?!",
#  'D-Dammit...!',
#  'This is Penguin News!',
#  "According to reports we've just received,",
#  "it appears that the world's most evil military force, the Red Ribbon Army,",
#  'is preparing for an all-out assault on Penguin Village!',
#  'Citizens are urged to shut themselves inside and to not come out!',
#  'I repeat...!',
#  'This for real?',
#  '--Hurry! Hurry!\\N--I am!',
#  "I can't move...! Dammit...!",
#  "H-Hey! What's wrong?!",
#  'Are you alright?',
#  "Dad. It's because of his psychic abilities.",
#  'What?',
#  'Is he a friend of yours?',
#  "No...! He's a bad guy...!",
#  "You're mine now!",
#  "It looks like that's a radar there in your hand...",
#  "I've collected a lot of presents!",
#  'Give me that!',
#  'Y-You jerk...! Give me back my radar...!',
#  'Um... that belongs to him...',
#  "If you value your lives, you'll mind your own business.",
#  "Oh, and I'll be taking this plane, too.",
#  "Take it...? But it's still not...",
#  'Dammit...!',
#  'Oh, yes. I nearly forgot the most important part.',
#  'You need to die...',
#  'What are you doing?!',
#  'W-What are you doing...?!',
#  'Making a shish kebab out of you.',
#  'Darn you...!',
#  'Arale! Go play a rough game of pro-wrestling with that guy!',
#  'Okay! Yay!',
#  'Die!',
#  'Arale Kick!',
#  'Wait for me!',
#  'Wait! Wait for me!',
#  'I caught up with you!',
#  'Head-butt!',
#  'Head-butt!',
#  'Look at him fly!',
#  'I can move now!',
#  "Yay! I'm all better!",
#  'What a big haul!',
#  'Your Majesty!',
#  'T-Terrible news!',
#  'P-Police...!',
#  'What?! Police?!',
#  "They're here to take back the special metal we stole from them!",
#  "I won't let them have it!",
#  'I know!',
#  'The Red Ribbon Army!',
#  'I did it! I did it!',
#  'Congratulations!',
#  'For such a rare occasion.',
#  'Damn it!',
#  'Fire!',
#  'Ow! Flee!',
#  'Y-Yes, sir!',
#  "You're not getting away from me!",
#  '--We did it!\\N--We defeated Red Ribbon!',
#  'Hurray!',
#  'I guess starting tomorrow, we go back to working part-time jobs...',
#  'Y-Your Majesty!',
#  'Your Majesty!',
#  "--I'm back!\\N--Welcome back!",
#  '--That was fun!\\N--What happened to him?!',
#  'I beat him up and sent him flying really far away!',
#  'You sent him flying really far away?!',
#  "You can't see him anymore...",
#  "Y-You're amazing!",
#  "Even though you're so tiny!",
#  'And my friend Obochaman is strong, too!',
#  "There's tons of guys stronger than me...",
#  'I need to train even more!',
#  'Oh, yeah! The Dragon Balls!',
#  'The Dragon Balls...',
#  "They're here!",
#  "Where's the Dragon Radar...?",
#  'Oh, yeah! He put it in his pocket!',
#  "I'm stuck... There's nothing I can do...",
#  "I could have Bulma make me another one, but I don't know the way back.",
#  "I can't look for the balls, either...",
#  'Shall I make you a new radar?',
#  'You...? Really?!',
#  'Can I have some of your airplane parts, Dad?',
#  'I memorized it when I saw it earlier.',
#  'You say you memorized it, but still, how are you...',
#  'W-What is that?!',
#  'Here.',
#  "It's exactly the same!",
#  'Awesome! Thanks!',
#  "You're welcome.",
#  'Genius certainly runs in the family!',
#  'Okay!',
#  'Thanks for everything, you guys!',
#  "The next time there's a Tenkaichi\\NTournament, you should enter it!",
#  'See you later!',
#  "G'bye!",
#  "G'bye!",
#  'So who exactly was that, anyway?',
#  "Yes. Unfortunately, I don't have the Dragon Balls...",
#  "But I did acquire the enemy's radar.",
#  'What?! Is that the truth?!',
#  'Yes. There is no mistake.',
#  'Very well. Return to HQ at once!',
#  "--Well, about that...\\N--What's wrong?!",
#  'At once...',
#  '...might be...',
#  '...a little...',
#  '...out of the question...',
#  '"The Magical Fire-Eating Bird"',
#  'Well?',
#  'Hold on...',
#  'Come on!',
#  'Aha! Here we are!',
#  'So the rumors were true, after all.',
#  'Is there any chance of putting it out?',
#  'Heck, no! Nobody could put this monster of a fire out!',
#  "Hi! It's been a while!",
#  'Let me see...',
#  'Who might you be again?',
#  "It's me!",
#  "Don't tell me you've forgotten?",
#  'How\'ve you been, Urigome? ["blockhead"]',
#  "It's Umigame.",
#  'And who might this be?',
#  "I'm Son Goku's wife.",
#  'Wife...?',
#  'Is the old-timer around?',
#  'The Turtle Hermit?',
#  "He hasn't returned from the\\NTenkaichi Tournament yet.",
#  'Eh?',
#  "Oh, that's right...",
#  'The tournament just ended a short while ago...',
#  "So it'll take a while for them all to get home...",
#  'Do you need the Turtle Hermit to help you with something?',
#  'We want the Basho Fan.',
#  'The one that he threw away after using it as a pot stand?',
#  'I doubt we could ever find it now...',
#  'That was several hundreds of years ago, after all.',
#  "That's not what we're here for, though.",
#  'Eh? Make one?',
#  "We heard there's an old book that tells how to make one!",
#  "If you're looking for old books, there are several in the back of the closet.",
#  'Hurry! Show us!',
#  'Certainly. No problem at all.',
#  "Let's go!",
#  'Here we are!',
#  'Basho Fan... Basho Fan...',
#  "Let's see...",
#  'Oh! Here it is!',
#  'One swing of this mighty fan will cause a heavy gale,',
#  'two swings will summon the thunderclouds,',
#  'and three swings will bring down a torrential rain!',
#  'It is made of the feathers of the magical Fire-Eating Bird,',
#  'which dwells inside the crater of Mt. Kiwi, at the southern end of the world.',
#  'The Fire-Eating Bird?',
#  "As its name implies, it's a bird that consumes fire.",
#  "That's it!",
#  'Are you cold?',
#  'No, your back is nice and warm.',
#  '--Is that it?\\N--I think it might be.',
#  "It's so hot...!",
#  'Watch your step, Chichi!',
#  'A bird that lives by eating fire? How weird...',
#  "Isn't it just a fairy tale, though?",
#  'Dunno.',
#  "But we don't have any other clues, so...",
#  'What is it?',
#  "Don't you hear it, Chichi?",
#  "W-What's that sound?",
#  'The Fire-Eating Bird...!',
#  "I-It's getting closer!",
#  "Be careful! It's dark in...!",
#  "Don't move, Chichi!",
#  'Sorry for waking you up!',
#  'Good thing we chose to do this in the morning!',
#  'But who do you suppose they are?',
#  "They're probably looking for the bird, too.",
#  'We better look sharp.',
#  "They might've already found it!",
#  "Let's hurry!",
#  "It's okay...",
#  'Sorry we woke you up!',
#  'Huh?',
#  'Stop!',
#  'That was close...',
#  'Chichi!',
#  'Goku!',
#  'Are you okay?',
#  "I-I'm fine...",
#  'But...',
#  'What is it?',
#  "What's the matter?!",
#  'What a humongous egg!',
#  "It might be that Fire-Eating Bird's egg...!",
#  'Stop right there!',
#  "Don't touch that egg!",
#  'Goku! Hurry up!',
#  "Is this the Fire-Eating Bird's egg, Mister?",
#  "That's right.",
#  'Who are you two?!',
#  "I'm Son Goku!",
#  "I'm his wife!",
#  "We're looking for the Fire-Eating Bird.",
#  "Where's the mother bird?",
#  "There isn't one.",
#  'It died. A long time ago.',
#  'Forty years ago, this mountain exploded in a violent eruption,',
#  'during which the Fire-Eating Bird died when it was crushed by a boulder.',
#  'The legendary Fire-Eating Bird no longer exists in this world.',
#  'All that remains is that single egg.',
#  "It's amazing that it was able to stay alive these past forty years...",
#  'The heat of this volcano kept the frail creature alive.',
#  "It's a miracle of Mother Nature!",
#  'When will it turn into a chick?!',
#  "I haven't the slightest. I'm not even sure it will hatch at all.",
#  "We're back to square one, then...",
#  "Let's go back and see Fortuneteller Baba.",
#  'Who are you?!',
#  "--We're here for the egg.\\N--What?!",
#  "We're extremely grateful that you found the egg for us!",
#  "Huh? Aren't they...?",
#  'The man whose face strikes fear in the hearts of even the worst of evildoers!',
#  'Robbery! Tattle-telling! Speeding!',
#  "Blackmail! Stealing other people's food!",
#  "He'll do anything if it's for money!",
#  'His name: Mister Pilaf Daimao!',
#  "H-He's...",
#  'You know him?',
#  'What a beautiful egg!',
#  "Beautiful because it's the only one in the world!",
#  'I could sell this to an obsessed fan for 100 million zeni!',
#  'And with that much, world domination will finally be more than a pipe dream!',
#  "That's right!",
#  "You're all mine!",
#  'Keep your filthy hands off of it!',
#  'What?! You!',
#  'Right.',
#  'Hey, you, girl. Come over here.',
#  "I'll have you know I'm someone's wife!",
#  'Come on! Just do it!',
#  'Aha! Tricked you!',
#  'Hand over the egg if you want her to live!',
#  'Wow! What a cute hat!',
#  'You look like a baby!',
#  "Think I'm bluffing?!",
#  "I'll do it if I have to!",
#  "I'm serious!",
#  "I could swear we've seen him somewhere before...",
#  'Yeah, I was just thinking the same thing...',
#  "Hey, what's his name?",
#  'Goku. Son Goku.',
#  '--Son Goku?\\N--Son Goku, huh?',
#  'Son Goku?!',
#  'Shuu! Mai!',
#  'Put the girl in a world of pain!',
#  'H-H-Help...!',
#  "Oh, no you don't!",
#  'Damn it!',
#  'N-Now I remember!',
#  "Y-You're Son Goku...!",
#  "Well, don't give up, Mister!",
#  'You too.',
#  'I hope it hatches.',
#  'An eruption?',
#  'Oh, no...!',
#  "It's the...",
#  'Am I dreaming?\\NThe Fire-Eating Bird is still alive...!',
#  "That's the Fire-Eating Bird?",
#  "It wasn't dead after all!",
#  'Watch out!',
#  'We have to get out of here!',
#  "If you're hungry, then eat more!",
#  "Good for you, your child's still alive!",
#  'We have to leave, too!',
#  'Goku! The feathers!',
#  'Look!',
#  'Feathers!',
#  'Hurray!',
#  'What does it mean?',
#  'These can put out the fire?',
#  'What are you doing?',
#  "I heard we could make a Basho Fan out of the Fire-Eating Bird's feathers...",
#  'A Basho Fan?',
#  'Ah, you mean that powerful fan?',
#  'That story you heard was just a bunch of nonsense.',
#  'The Fire-Eating Bird would run out of food',
#  'if its feathers could put out fires...',
#  'Then that book was...',
#  '...obviously pure nonsense, you moron!',
#  'I was drunk when I wrote that crap!',
#  'I guess we really are back at square one...',
#  'The Basho Fan, eh?',
#  'Hold on, I once heard where it was.',
#  '--Really?!\\N--Yes.',
#  "I've heard that to the north of here there's this place called Ice Mountain,",
#  'which even the Fire-Eating\\NBird is too scared to get near...',
#  "Thanks! Let's go, Chichi!",
#  'Or was it to the west?',
#  'Crush his heart!',
#  'You!',
#  'Run away, Son!',
#  'Get away from here!',
#  "You ain't goin' anywhere. You're gonna pay for kicking me like that!",
#  "Precisely. A fool such as yourself won't learn your lesson without dying first.",
#  '"Goku-- Anger at Full Power!!"',
#  'This is terrible.',
#  "But Metro West hasn't been destroyed yet.",
#  "That's because Tenshinhan is doing something to prevent it, no doubt.",
#  "What's happening right now?",
#  "Nothin' better happen to Tenshinhan!",
#  "Or else someone's gonna pay!",
#  'You got that right!',
#  'Huh?',
#  'Oh, are we going on a picnic?',
#  "Now you've done it.",
#  'Despite cheating death, you come to defy me once more...',
#  "That's right. I'm not gonna die until I kill you!",
#  'Ignorant fool.',
#  "It seems you still don't understand.",
#  "I'm even more powerful than I was before!",
#  ...]

# %%
def remove_stutter(text):
    stutter_pattern = re.compile(r'\b(\w)-\1(\w+)\b', re.IGNORECASE)
    corrected_text = stutter_pattern.sub(r'\1\2', text)
    return corrected_text

def get_and_preprocess_dbz_data():
    text = [example for example in load_dataset("Fishball02/anime-subtitle-dragon-ball")['train']['text']]
    text = [' '.join(t.replace('\\N', ' ').replace('.', ' ').replace('\'', '').split()) for t in text]
    text = [remove_stutter(t) for t in text]
    text = [' '.join(t.replace('-', ' ').split()) for t in text]
    return text

# %%
nltk.download('stopwords')
nltk.download('punkt')

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    return ' '.join(word for word in text.split() if word.lower() not in stop_words)

def plot_distribution(text):
    text = [remove_stopwords(t) for t in text]
    lengths = [len(example.split()) for example in text]
    plt.hist(lengths, bins=50)
    plt.xlabel('Sequence Length')
    plt.ylabel('Frequency')
    plt.show()

def plot_wordcloud(text):
    text = [remove_stopwords(t) for t in text]
    text = ' '.join([t for t in text])
    tokens = nltk.word_tokenize(text)
    processed_text = ' '.join(tokens)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(processed_text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')  # Turn off axis
    plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Amram\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amram\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = get_and_preprocess_dbz_data()
plot_distribution(text)
plot_wordcloud(text)

# %%
class DragonBallZChatbotDataset(Dataset):
    def __init__(self, ds, tokenizer, seq_len):
        super().__init__()
        self.ds = ds
        self.tokenizer = tokenizer
        self.seq_len = seq_len
        self.sos_token = tokenizer.token_to_id('[SOS]')
        self.eos_token = tokenizer.token_to_id('[EOS]')
        self.pad_token = tokenizer.token_to_id('[PAD]')

    def __len__(self):
        return len(self.ds) - 1  # Since we are using pairs

    def __getitem__(self, index):
        context = self.ds[index]['text']
        response = self.ds[index + 1]['text']
        context_tokens = self.tokenizer.encode(context).ids
        response_tokens = self.tokenizer.encode(response).ids
        
        # Add special tokens
        context_tokens = [self.sos_token] + context_tokens + [self.eos_token]
        response_tokens = [self.sos_token] + response_tokens + [self.eos_token]
        
        # Padding
        context_tokens = context_tokens[:self.seq_len] + [self.pad_token] * (self.seq_len - len(context_tokens))
        response_tokens = response_tokens[:self.seq_len] + [self.pad_token] * (self.seq_len - len(response_tokens))
        
        return torch.tensor(context_tokens[:self.seq_len], dtype=torch.long), torch.tensor(response_tokens[:self.seq_len], dtype=torch.long)

# %%
def get_or_build_tokenizer(config: dict, ds = None):
    tokenizer_path = Path(config['tokenizer_file'])
    if not tokenizer_path.exists():
        tokenizer = Tokenizer(WordLevel(unk_token='[UNK]'))
        tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()
        trainer = trainers.WordLevelTrainer(
            special_tokens=['[UNK]', '[PAD]', '[SOS]', '[EOS]'],
            min_frequency=2
        )

        tokenizer.train_from_iterator(ds, trainer=trainer)
        tokenizer.save(str(tokenizer_path))
    else:
        tokenizer = Tokenizer.from_file(str(tokenizer_path))

    return tokenizer

# %%
def get_ds(config: dict):
    # Load the Dragon Ball Z dataset
    # ds_raw = get_and_preprocess_dbz_data()
    ds_raw = load_dataset("Fishball02/anime-subtitle-dragon-ball")['train']
    
    # Build or load the tokenizer
    tokenizer = get_or_build_tokenizer(config, ds_raw)

    # Split the dataset into training and validation sets
    train_ds_size = int(0.9 * len(ds_raw))
    val_ds_size = len(ds_raw) - train_ds_size
    train_ds_raw, val_ds_raw = random_split(ds_raw, (train_ds_size, val_ds_size))

    # Create the dataset
    train_ds = DragonBallZChatbotDataset(train_ds_raw, tokenizer, config['seq_len'])
    val_ds = DragonBallZChatbotDataset(val_ds_raw, tokenizer, config['seq_len'])

    return train_ds, val_ds

# %%
def custom_collate_fn(batch):
    filtered_batch = []
    for item in batch:
        try:
            context, response = item
            if context is not None and response is not None:
                filtered_batch.append((context, response))
        except ValueError:
            # Skip the problematic sample
            continue
    return torch.utils.data.dataloader.default_collate(filtered_batch)

# %%
def print_gpu_utilization():
    pynvml.nvmlInit()
    handle = pynvml.nvmlDeviceGetHandleByIndex(0)
    info = pynvml.nvmlDeviceGetMemoryInfo(handle)
    print(f"GPU memory occupied: {info.used // 1024 ** 2:.2f} MB.")

# %%
def train_chatbot(config: dict):
    model_path = Path('./dbzLLM.pt')
    if not model_path.exists():
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print(f'The neural network will be running on {device}')
        train_ds, val_ds = get_ds(config=config)
        train_loader = DataLoader(train_ds, batch_size=config['batch_size'], shuffle=True, collate_fn=custom_collate_fn, pin_memory=True)
        val_loader = DataLoader(val_ds, batch_size=config['batch_size'], shuffle=False, collate_fn=custom_collate_fn, pin_memory=True)
        vocab_size = len(get_or_build_tokenizer(config).get_vocab())
        model = build_transformer(
            vocab_size, vocab_size, config['seq_len'], config['seq_len'], 
            d_model=config['d_model'], N=config['N'], 
            h=config['h'], dropout=config['dropout'], d_ff=config['d_ff']
        )
        
        model.to(device)
        criterion = nn.CrossEntropyLoss(ignore_index=train_ds.pad_token)
        optimizer = torch.optim.Adam(model.parameters(), lr=config['learning_rate'])
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5, patience=3)
        scaler = GradScaler()
        best_val_loss = float('inf')
        patience = 10
        patience_counter = 0
        for epoch in trange(config['num_epochs']):
            model.train()
            train_loss = 0
            total_batches = len(train_loader)
            for idx, (context, response) in enumerate(train_loader):
                progress = 100 * ((idx + 1) / total_batches)
                if int(progress) % 10 == 0:
                    print(f'Epoch {epoch} is {progress:.2f}% completed')
                    
                context = context.to(device, non_blocking=True)
                response = context.to(device, non_blocking=True)
                optimizer.zero_grad()
                context_embed = model.src_embed(context)
                response_embed = model.tgt_embed(response)
                
                with autocast():
                    output = model(context, response)
                    loss = criterion(output.view(-1, vocab_size), response.view(-1))

                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()                
                train_loss += loss.item()
    
            train_loss /= len(train_loader)
            print_gpu_utilization()
            print(f'Epoch {epoch + 1}/{config["num_epochs"]}, Loss: {loss.item()}')
        
            model.eval()
            val_loss = 0
            with torch.no_grad():
                for context, response in val_loader:
                    context = context.to(device, non_blocking=True)
                    response = response.to(device, non_blocking=True)
                    with autocast():
                        output = model(context, response)
                        loss = criterion(output.view(-1, vocab_size), response.view(-1))
                
                val_loss += loss.item()

            val_loss /= len(val_loader)
            print(f'Epoch {epoch + 1}/{config["num_epochs"]}, Validation Loss: {val_loss}')
        
            scheduler.step(val_loss)
    
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
            else:
                patience_counter += 1
    
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

            
        torch.save(model.state_dict(), './dbzLLM.pt')
    else:
        pass

# %%
def load_chatbot(device, vocab_size: int):
    model = build_transformer(src_vocab_size=vocab_size, 
                              tgt_vocab_size=vocab_size, 
                              src_seq_len=config['seq_len'], 
                              tgt_seq_len=config['seq_len'], 
                              d_model=config['d_model'], 
                              N=config['N'], 
                              h=config['h'], 
                              dropout=config['dropout'], 
                              d_ff=config['d_ff']
                             )
    
    model.load_state_dict(torch.load('./dbzLLM.pt'))
    model.to(device)
    model.eval()
    return model

def preprocess_sentence(sentence, tokenizer, seq_len, device):
    tokens = tokenizer.encode(sentence).ids
    tokens = [tokenizer.token_to_id('[SOS]')] + tokens + [tokenizer.token_to_id('[EOS]')]
    tokens = tokens[:seq_len] + [tokenizer.token_to_id('[PAD]')] * (seq_len - len(tokens))
    return torch.tensor(tokens, dtype=torch.long).unsqueeze(0).to(device)

def chatbot_predict(model, sentence, tokenizer, seq_len, device):
    model.eval()
    input_tokens = preprocess_sentence(sentence, tokenizer, seq_len, device)
    
    
    with torch.no_grad():
        output_tokens = model(input_tokens, input_tokens)
        
    output_ids = output_tokens.argmax(dim=-1).squeeze().tolist()
    output_sentence = tokenizer.decode(output_ids, skip_special_tokens=True)
    return output_sentence

def chat(config):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    tokenizer = get_or_build_tokenizer(config)
    vocab_size = len(tokenizer.get_vocab())
    chatbot = load_chatbot(device=device, vocab_size=vocab_size)
    name = 'Tim'
    while True:
        command = print('Type `quit` to end chatting')    
        sentence = input('You: ')
        if 'quit' == sentence:
            break
            
        output = chatbot_predict(chatbot, sentence, tokenizer, config['seq_len'], device)
        print(f'{name}: {output}')

# %%
# Configuration dictionary
config = {
    'tokenizer_file': './tokenizer.json',
    'dropout': 0.1,
    'seq_len': 128,
    'batch_size': 32,
    'd_model': 512,
    'h': 8,
    'N': 6,
    'num_decoder_layers': 6,
    'd_ff': 2048,
    'num_epochs': 100,
    'learning_rate': 1e-4
}

# %%
train_chatbot(config=config)
# Out:
# The neural network will be running on cuda
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]
# Epoch 0 is 0.13% completed
# Epoch 0 is 0.26% completed
# Epoch 0 is 0.39% completed
# Epoch 0 is 0.52% completed
# Epoch 0 is 0.65% completed
# Epoch 0 is 0.78% completed
# Epoch 0 is 0.92% completed
# Epoch 0 is 10.07% completed
# Epoch 0 is 10.20% completed
# Epoch 0 is 10.33% completed
# Epoch 0 is 10.46% completed
# Epoch 0 is 10.59% completed
# Epoch 0 is 10.72% completed
# Epoch 0 is 10.85% completed
# Epoch 0 is 10.98% completed
# Epoch 0 is 20.00% completed
# Epoch 0 is 20.13% completed
# Epoch 0 is 20.26% completed
# Epoch 0 is 20.39% completed
# Epoch 0 is 20.52% completed
# Epoch 0 is 20.65% completed
# Epoch 0 is 20.78% completed
# Epoch 0 is 20.92% completed
# Epoch 0 is 30.07% completed
# Epoch 0 is 30.20% completed
# Epoch 0 is 30.33% completed
# Epoch 0 is 30.46% completed
# Epoch 0 is 30.59% completed
# Epoch 0 is 30.72% completed
# Epoch 0 is 30.85% completed
# Epoch 0 is 30.98% completed
# Epoch 0 is 40.00% completed
# Epoch 0 is 40.13% completed
# Epoch 0 is 40.26% completed
# Epoch 0 is 40.39% completed
# Epoch 0 is 40.52% completed
# Epoch 0 is 40.65% completed
# Epoch 0 is 40.78% completed
# Epoch 0 is 40.92% completed
# Epoch 0 is 50.07% completed
# Epoch 0 is 50.20% completed
# Epoch 0 is 50.33% completed
# Epoch 0 is 50.46% completed
# Epoch 0 is 50.59% completed
# Epoch 0 is 50.72% completed
# Epoch 0 is 50.85% completed
# Epoch 0 is 50.98% completed
# Epoch 0 is 60.00% completed
# Epoch 0 is 60.13% completed
# Epoch 0 is 60.26% completed
# Epoch 0 is 60.39% completed
# Epoch 0 is 60.52% completed
# Epoch 0 is 60.65% completed
# Epoch 0 is 60.78% completed
# Epoch 0 is 60.92% completed
# Epoch 0 is 70.07% completed
# Epoch 0 is 70.20% completed
# Epoch 0 is 70.33% completed
# Epoch 0 is 70.46% completed
# Epoch 0 is 70.59% completed
# Epoch 0 is 70.72% completed
# Epoch 0 is 70.85% completed
# Epoch 0 is 70.98% completed
# Epoch 0 is 80.00% completed
# Epoch 0 is 80.13% completed
# Epoch 0 is 80.26% completed
# Epoch 0 is 80.39% completed
# Epoch 0 is 80.52% completed
# Epoch 0 is 80.65% completed
# Epoch 0 is 80.78% completed
# Epoch 0 is 80.92% completed
# Epoch 0 is 90.07% completed
# Epoch 0 is 90.20% completed
# Epoch 0 is 90.33% completed
# Epoch 0 is 90.46% completed
# Epoch 0 is 90.59% completed
# Epoch 0 is 90.72% completed
# Epoch 0 is 90.85% completed
# Epoch 0 is 90.98% completed
# Epoch 0 is 100.00% completed
# GPU memory occupied: 5903.00 MB.
# Epoch 1/100, Loss: 7.580151617503361e-08
#   1%|▊                                                                              | 1/100 [02:00<3:18:34, 120.35s/it]
# Epoch 1/100, Validation Loss: 1.6646434296356295e-10
# Epoch 1 is 0.13% completed
# Epoch 1 is 0.26% completed
# Epoch 1 is 0.39% completed
# Epoch 1 is 0.52% completed
# Epoch 1 is 0.65% completed
# Epoch 1 is 0.78% completed
# Epoch 1 is 0.92% completed
# Epoch 1 is 10.07% completed
# Epoch 1 is 10.20% completed
# Epoch 1 is 10.33% completed
# Epoch 1 is 10.46% completed
# Epoch 1 is 10.59% completed
# Epoch 1 is 10.72% completed
# Epoch 1 is 10.85% completed
# Epoch 1 is 10.98% completed
# Epoch 1 is 20.00% completed
# Epoch 1 is 20.13% completed
# Epoch 1 is 20.26% completed
# Epoch 1 is 20.39% completed
# Epoch 1 is 20.52% completed
# Epoch 1 is 20.65% completed
# Epoch 1 is 20.78% completed
# Epoch 1 is 20.92% completed

# %%
chat(config)
